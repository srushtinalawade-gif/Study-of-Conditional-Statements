# %% [markdown]
# <a href="https://colab.research.google.com/github/srushtinalawade-gif/Study-of-Conditional-Statements/blob/main/Practical6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Study Of Conditional Statements
#
# ## Name- Srushti J. Nalawade
# ## PRN- 25070123157
# ## Batch- ENTC A1
# ## Date- 30 January, 2026

# %%
# Check whether a number is positive or negative
num=int(input('Enter a number:'))
if num>=0:
  print('Number is positive')
else:
  print('Number is negative')
# Out:
# Enter a number:-1
# Number is negative

# %%
num=int(input('Enter a number:'))
if num>0:
  print('Number is positive')
elif num<0:
  print('Number is negative')
else:
  print('Number is 0')
# Out:
# Enter a number:0
# Number is 0

# %%
# Even- Odd
num=int(input('Enter Number:'))
if num%2==0:
  print('Number is even')
else:
  print('Number is odd')
# Out:
# Enter Number:6
# Number is even

# %%
# Find the largest number
num1=int(input('Enter Number 1:'))
num2=int(input('Enter Number 2:'))

if num1>num2:
  print(num1,' is greater')
elif num1==num2:
  print('Both numbers are equal')
else:
  print(num2, ' is greater')
# Out:
# Enter Number 1:45
# Enter Number 2:67
# 67  is greater

# %%
num1=int(input('Enter Number 1:'))
num2=int(input('Enter Number 2:'))
num3=int(input('Enter Number 3:'))

if num1>num2 | num1>num3:
  print(num1,' is greater')
elif num1<num3:
  print(num2,' is greater')
elif num1==num2 | num1==num3:
  print('The numbers are equal')
else:
  print(num3,' is greater')
# Out:
# Enter Number 1:5
# Enter Number 2:7
# Enter Number 3:6
# 7  is greater

# %%
98# Marks Avg
ecsf=int(input('Enter marks:'))
dcld=int(input('Enter marks:'))
amt=int(input('Enter marks:'))
cla=int(input('Enter marks:'))
feee=int(input('Enter marks:'))

avg= (ecsf+dcld+amt+cla+feee)/5
avg_percent=avg*100

if avg_percent >= 90:
  print("Grade: A")
elif avg_percent>=80 and avg_percent<90:
  print("Grade: B")
elif avg_percent>=70 and avg_percent< 80:
  print("Grade: c")
elif avg_percent>=60 and avg_percent < 70:
  print("Grade: D")
else:
  print('Fail')
# Out:
# Enter marks:90
# Enter marks:98
# Enter marks:97
# Enter marks:89
# Enter marks:91
# Grade: A

# %%
# Leap Year or not
year=int(input('Enter year:'))

if (year%4==0 and year%100!=0) or (year%400==0):
  print(year,' is a leap year')
else:
  print(year,' is not a leap year')
# Out:
# Enter year:6789
# 6789  is not a leap year

# %%
#6. Check whether a leap year is a leap year
year=int(input("Enter Year:"))

if (year%4==0 and year%100!=0) or (year%400==0):
  print(year,"is a Leap Year")
else:
  print(year,"is not a leap year")
# Out:
# Enter Year:2024
# 2024 is a Leap Year

# %%
#7. Python Program to check if a Date is valid and Print the Incremented Date if it is valid'''
date=input("Enter the date in format {dd/mm/yyyy}")
dd,mm,yyyy=date.split("/")
dd=int(dd)
mm=int(mm)
yyyy=int(yyyy)
if (mm==1 or mm==3 or mm==5 or mm==7 or mm==8 or mm==10 or mm==12):
  max1=31
elif(mm==4 or mm==6 or mm==9 or mm==11):
  max1=30
elif(yyyy%4==0 and yyyy%100!=0) or (yyyy%400==0):
  max1=29
else:
  max1=28

if(mm<1 or mm>12):
  print("The date is invalid.")
elif(dd<1 or dd>max1):
  dd=1
  mm=mm+1
  print("The incremented date is:",dd,mm,yyyy)
elif(dd==31 and mm==12):
  dd=1
  mm=1
  yyyy=yyyy+1
  print("The incremented date is:",dd,mm,yyyy)
else:
  dd=dd+1
  print("The incremented date is:",dd,mm,yyyy)
# Out:
# Enter the date in format {dd/mm/yyyy}32/13/2026
# The date is invalid.

# %%
# Gross Salary
basic=float(input('Enter basic salary:'))
if basic<= 10000:
  hra=basic*0.20
  da=basic*0.80
  total=basic+hra+da
  print('Total Salary:',total)
elif basic>10000 and basic<=20000:
  hra=basic*0.25
  da=basic*0.90
  total=basic+hra+da
  print('Total Salary:',total)
else:
  hra=basic*0.30
  da=basic*0.95
  total=basic+hra+da
  print('Total Salary:',total)
# Out:
# Enter basic salary:12000
# Total Salary: 25800.0

# %%
# income tax
income=float(input('Enter annual income:'))
if income>250500 and income<=500000:
  tax=income*0.05
elif income>500000 and income<1000000:
  tax=income*0.20
elif income<1000000:
  tax=income*0.30

print("Income Tax applicable:",tax)
# Out:
# Enter annual income:125000
# Income Tax applicable: 37500.0
